# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://huggingface.co/datasets/yili7eli/TAM
# Out:
# fatal: destination path 'TAM' already exists and is not an empty directory.

# %%
#%rm -rf FVAB-TAM-Gruppo16
# !git clone https://github.com/GiRuni/FVAB-TAM-Gruppo16
# Out:
# fatal: destination path 'FVAB-TAM-Gruppo16' already exists and is not an empty directory.

# %%
# %cd FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam
# Out:
# /content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam

# %%
# !pip install -r requirements.txt

# %%
# !sudo apt-get update
# !sudo apt-get install texlive-xetex
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://cli.github.com/packages stable/main amd64 Packages [354 B]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [99.9 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,764 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [4,046 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,307 kB]
# ...

# %%
# !pip install tools
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.2 MB/s eta 0:00:00
# ...

# %%
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
import nltk
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
# !unzip -q -n /content/TAM/data.tar -d /content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam

# %%
# !python /content/FVAB-TAM-Gruppo16/Fase_3/coco_polygon_binary_masks_all.py
# Out:
# loading annotations into memory...
# Done (t=0.49s)
# creating index...
# index created!
# /content/FVAB-TAM-Gruppo16/Fase_3/coco_polygon_binary_masks_all.py:78: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   img = Image.fromarray(mask_uint8, mode="L")
# Done. Wrote masks to: /content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/masks

# %%
# !python /content/FVAB-TAM-Gruppo16/Fase_3/merge_masks.py
# Out:
# [OK] 000000311518 relation 1 (1 masks) -> /content/FVAB-TAM-Gruppo16/Fase_3/merged_masks/000000311518/1.png
# [OK] 000000311518 relation 1_boat (1 masks) -> /content/FVAB-TAM-Gruppo16/Fase_3/merged_masks/000000311518/1_boat.png
# [OK] 000000311518 relation 2 (1 masks) -> /content/FVAB-TAM-Gruppo16/Fase_3/merged_masks/000000311518/2.png
# [OK] 000000311518 relation 2_boat (1 masks) -> /content/FVAB-TAM-Gruppo16/Fase_3/merged_masks/000000311518/2_boat.png
# [OK] 000000313034 relation 1 (1 masks) -> /content/FVAB-TAM-Gruppo16/Fase_3/merged_masks/000000313034/1.png
# [OK] 000000313034 relation 1_man (1 masks) -> /content/FVAB-TAM-Gruppo16/Fase_3/merged_masks/000000313034/1_man.png
# [OK] 000000313034 relation 2 (1 masks) -> /content/FVAB-TAM-Gruppo16/Fase_3/merged_masks/000000313034/2.png
# [OK] 000000313034 relation 2_woman (1 masks) -> /content/FVAB-TAM-Gruppo16/Fase_3/merged_masks/000000313034/2_woman.png
# ...

# %%
# %mv /content/FVAB-TAM-Gruppo16/Fase_4/new_eval_both.py /content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/
# %mv /content/FVAB-TAM-Gruppo16/Fase_2/tam_words.py /content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/

# %%
# !python /content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/new_eval_both.py
# Out:
# Images to evaluate: 5000
# Spatial config: 13 prepositions loaded
# 2026-06-29 15:28:21.936002: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# config.json: 1.20kB [00:00, 8.22MB/s]
# model.safetensors.index.json: 56.4kB [00:00, 166MB/s]
# Fetching 2 files:   0% 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0% 0.00/3.99G [00:00<?, ?B/s]
#
# model-00002-of-00002.safetensors:   0% 0.00/429M [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   1% 25.1M/3.99G [00:01<04:42, 14.0MB/s]
# model-00001-of-00002.safetensors:   2% 67.1M/3.99G [00:03<02:45, 23.7MB/s]
# model-00001-of-00002.safetensors:   3% 134M/3.99G [00:04<01:56, 33.1MB/s]
# model-00001-of-00002.safetensors:   5% 201M/3.99G [00:04<01:06, 56.8MB/s]
# ...

# %%
# !python /content/FVAB-TAM-Gruppo16/Fase_4/compare.py "/content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/results_dual/results_mode_a.csv" "/content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/results_dual/results_mode_b.csv" "/content/results_comparison.csv"
# Out:
# Done. Wrote 34 rows.

# %%
# !zip -r /content/risultati /content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/results_dual
# !zip -r /content/heatmaps /content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/vis_results_dual
# Out:
#   adding: content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/results_dual/ (stored 0%)
#   adding: content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/results_dual/results_mode_b.csv (deflated 54%)
#   adding: content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/results_dual/summary_A.csv (deflated 90%)
#   adding: content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/results_dual/results_mode_a.csv (deflated 86%)
#   adding: content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/results_dual/summary_B.csv (deflated 48%)
#   adding: content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/results_dual/generated_all.csv (deflated 39%)
#   adding: content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/vis_results_dual/ (stored 0%)
#   adding: content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/vis_results_dual/000000311518/ (stored 0%)
#   adding: content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/vis_results_dual/000000311518/layer_028_modeB/ (stored 0%)
# ...

# %%
#!python /content/FVAB-TAM-Gruppo16/Fase_4/compare.py "/content/results_mode_a.csv" "/content/results_mode_b.csv" "/content/results_comparison.csv"
