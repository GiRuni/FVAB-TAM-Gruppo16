# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://huggingface.co/datasets/yili7eli/TAM
# Out:
# Cloning into 'TAM'...
# remote: Enumerating objects: 10, done.
# remote: Total 10 (delta 0), reused 0 (delta 0), pack-reused 10 (from 1)
# Receiving objects: 100% (10/10), done.

# %%
# !git clone https://github.com/GiRuni/FVAB-TAM-Gruppo16
# Out:
# Cloning into 'FVAB-TAM-Gruppo16'...
# remote: Enumerating objects: 309, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 309 (delta 42), reused 18 (delta 18), pack-reused 245 (from 1)
# Receiving objects: 100% (309/309), 7.22 MiB | 19.46 MiB/s, done.
# Resolving deltas: 100% (71/71), done.

# %%
# %cd FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam
# Out:
# /content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam

# %%
# !pip install -r requirements.txt

# %%
# !sudo apt-get update
# !sudo apt-get install texlive-xetex
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [95.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,646 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [77.8 kB]
# ...

# %%
# !pip install tools
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.2 MB/s eta 0:00:00
# ...

# %%
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
import nltk
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
# !unzip /content/TAM/data.tar -d /content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam
# Out:
# Output streaming troncato alle ultime 5000 righe.
#   inflating: /content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/data/OpenPSG/image/000000476827.jpg
#   inflating: /content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/data/OpenPSG/image/000000364508.jpg
#   inflating: /content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/data/OpenPSG/image/000000097683.jpg
#   inflating: /content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/data/OpenPSG/image/000000317934.jpg
#   inflating: /content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/data/OpenPSG/image/000000008005.jpg
#   inflating: /content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/data/OpenPSG/image/000000383330.jpg
#   inflating: /content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/data/OpenPSG/image/000000070702.jpg
#   inflating: /content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/data/OpenPSG/image/000000396736.jpg
#   inflating: /content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/data/OpenPSG/image/000000523244.jpg
# ...

# %%
# !python /content/FVAB-TAM-Gruppo16/Fase_3/coco_polygon_binary_masks_all.py
# Out:
# loading annotations into memory...
# Done (t=0.51s)
# creating index...
# index created!
# /content/FVAB-TAM-Gruppo16/Fase_3/coco_polygon_binary_masks_all.py:78: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   img = Image.fromarray(mask_uint8, mode="L")
# Done. Wrote masks to: /content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/masks

# %%
# !python /content/FVAB-TAM-Gruppo16/Fase_3/merge_masks.py
# Out:
# [OK] 000000000872 relation 2 (2 masks) -> /content/FVAB-TAM-Gruppo16/Fase_3/merged_masks/000000000872/2.png
# [OK] 000000000872 relation 3 (2 masks) -> /content/FVAB-TAM-Gruppo16/Fase_3/merged_masks/000000000872/3.png
# [OK] 000000001296 relation 1 (1 masks) -> /content/FVAB-TAM-Gruppo16/Fase_3/merged_masks/000000001296/1.png
# [OK] 000000001296 relation 2 (1 masks) -> /content/FVAB-TAM-Gruppo16/Fase_3/merged_masks/000000001296/2.png
# [OK] 000000032081 relation 2 (1 masks) -> /content/FVAB-TAM-Gruppo16/Fase_3/merged_masks/000000032081/2.png
# [OK] 000000010363 relation 1 (1 masks) -> /content/FVAB-TAM-Gruppo16/Fase_3/merged_masks/000000010363/1.png
# [OK] 000000010363 relation 2 (1 masks) -> /content/FVAB-TAM-Gruppo16/Fase_3/merged_masks/000000010363/2.png
# [OK] 000000010363 relation 3 (2 masks) -> /content/FVAB-TAM-Gruppo16/Fase_3/merged_masks/000000010363/3.png
# [OK] 000000011699 relation 1 (1 masks) -> /content/FVAB-TAM-Gruppo16/Fase_3/merged_masks/000000011699/1.png
# ...

# %%
# %mv /content/FVAB-TAM-Gruppo16/Fase_3/new_eval_words_merged.py /content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/
# %mv /content/FVAB-TAM-Gruppo16/Fase_2/tam_words.py /content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam/

# %%
# !python /content/FVAB-TAM-Gruppo16/tam-logit-lenses/ll_tam//new_eval_words_merged.py
# Out:
# Output streaming troncato alle ultime 5000 righe.
# --- 000000386457 ---
#   [SKIP] no query block for this image (query key: 386457)
#
# --- 000000386879 ---
#   [SKIP] no query block for this image (query key: 386879)
#
# --- 000000386912 ---
#   [SKIP] no query block for this image (query key: 386912)
#
# --- 000000387098 ---
#   [SKIP] no query block for this image (query key: 387098)
#
# --- 000000387148 ---
#   [SKIP] no query block for this image (query key: 387148)
#
# --- 000000387383 ---
#   [SKIP] no query block for this image (query key: 387383)
#
# --- 000000387387 ---
#   [SKIP] no query block for this image (query key: 387387)
#
# --- 000000387916 ---
#   [SKIP] no query block for this image (query key: 387916)
#
# --- 000000388056 ---
#   [SKIP] no query block for this image (query key: 388056)
#
# --- 000000388215 ---
#   [SKIP] no query block for this image (query key: 388215)
#
# --- 000000388258 ---
#   [SKIP] no query block for this image (query key: 388258)
#
# ...
